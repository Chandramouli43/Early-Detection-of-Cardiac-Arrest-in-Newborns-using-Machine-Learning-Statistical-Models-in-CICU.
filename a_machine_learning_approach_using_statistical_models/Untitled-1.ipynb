# %%
import pandas as pd
df=pd.read_csv(r"C:\Desktop\A_Machine_Learning_Approach_Using_Statistical_Models\A_Machine_Learning_Approach_Using_Statistical_Models\a_machine_learning_approach_using_statistical_models\Datasets.csv")

# %%
df
# Out:
#                                          Fid  Age_In_Days Sex ChestPainType  \
# 0     192.229.163.180-10.42.0.42-443-35305-6           40   M           ATA
# 1     203.205.179.172-10.42.0.151-80-44515-6           49   F           NAP
# 2    10.42.0.211-123.125.115.164-59145-443-6           37   M           ATA
# 3     182.22.120.252-10.42.0.151-443-43863-6           48   F           ASY
# 4      172.217.7.227-10.42.0.151-443-40198-6           54   M           NAP
# 5       172.217.6.202-10.42.0.42-443-41390-6           39   M           NAP
# 6     172.217.11.14-10.42.0.151-443-38578-17           45   F           ATA
# 7     172.217.10.142-10.42.0.151-443-51582-6           54   M           ATA
# 8           10.42.0.211-10.42.0.1-6198-53-17           37   M           ASY
# 9          10.42.0.211-10.42.0.1-26569-53-17           48   F           ATA
# 10    216.58.219.196-10.42.0.151-443-50803-6           37   F           NAP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 14 columns):
# Fid               918 non-null object
# Age_In_Days       918 non-null int64
# Sex               918 non-null object
# ChestPainType     918 non-null object
# RestingBP         918 non-null int64
# RestingECG        918 non-null object
# MaxHR             918 non-null int64
# ExerciseAngina    918 non-null object
# Oldpeak           918 non-null float64
# ST_Slope          918 non-null object
# slp               918 non-null int64
# caa               918 non-null int64
# thall             918 non-null int64
# HeartDisease      918 non-null int64
# dtypes: float64(1), int64(7), object(6)
# memory usage: 100.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
df["Sex"]=LabelEncoder().fit_transform(df["Sex"]) 
df["RestingECG"]=LabelEncoder().fit_transform(df["RestingECG"]) 
df["ExerciseAngina"]=LabelEncoder().fit_transform(df["ExerciseAngina"]) 
df["ST_Slope"]=LabelEncoder().fit_transform(df["ST_Slope"]) 
df["ChestPainType"]=LabelEncoder().fit_transform(df["ChestPainType"])

# %%
df
# Out:
#                                          Fid  Age_In_Days  Sex  ChestPainType  \
# 0     192.229.163.180-10.42.0.42-443-35305-6           40    1              1
# 1     203.205.179.172-10.42.0.151-80-44515-6           49    0              2
# 2    10.42.0.211-123.125.115.164-59145-443-6           37    1              1
# 3     182.22.120.252-10.42.0.151-443-43863-6           48    0              0
# 4      172.217.7.227-10.42.0.151-443-40198-6           54    1              2
# 5       172.217.6.202-10.42.0.42-443-41390-6           39    1              2
# 6     172.217.11.14-10.42.0.151-443-38578-17           45    0              1
# 7     172.217.10.142-10.42.0.151-443-51582-6           54    1              1
# 8           10.42.0.211-10.42.0.1-6198-53-17           37    1              0
# 9          10.42.0.211-10.42.0.1-26569-53-17           48    0              1
# 10    216.58.219.196-10.42.0.151-443-50803-6           37    0              2
# ...
